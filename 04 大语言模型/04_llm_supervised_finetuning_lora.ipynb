# %%
import subprocess
import os
os.environ['CURL_CA_BUNDLE'] = ''

result = subprocess.run('bash -c "source /etc/network_turbo && env | grep proxy"', shell=True, capture_output=True, text=True)
output = result.stdout
for line in output.splitlines():
    if '=' in line:
        var, value = line.split('=', 1)
        os.environ[var] = value

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, get_peft_model, prepare_model_for_kbit_training
from transformers import AutoModelForCausalLM, AutoTokenizer, TrainingArguments
from trl import SFTTrainer

# %% [markdown]
# ## Dataset

# %%
# import os
# os.environ['HTTP_PROXY'] = 'http://127.0.0.1:7890'
# os.environ['HTTPS_PROXY'] = 'http://127.0.0.1:7890'

# %%
train_dataset = load_dataset("tatsu-lab/alpaca", split="train")
# Out:
# README.md:   0%|          | 0.00/7.47k [00:00<?, ?B/s]
# (…)-00000-of-00001-a09b74b3ef9c3b56.parquet:   0%|          | 0.00/24.2M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/52002 [00:00<?, ? examples/s]

# %%
train_dataset
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output', 'text'],
#     num_rows: 52002
# })

# %%
# without input
train_dataset[0]
# Out:
# {'instruction': 'Give three tips for staying healthy.',
#  'input': '',
#  'output': '1.Eat a balanced diet and make sure to include plenty of fruits and vegetables. \n2. Exercise regularly to keep your body active and strong. \n3. Get enough sleep and maintain a consistent sleep schedule.',
#  'text': 'Below is an instruction that describes a task. Write a response that appropriately completes the request.\n\n### Instruction:\nGive three tips for staying healthy.\n\n### Response:\n1.Eat a balanced diet and make sure to include plenty of fruits and vegetables. \n2. Exercise regularly to keep your body active and strong. \n3. Get enough sleep and maintain a consistent sleep schedule.'}

# %%
print(train_dataset[0]['text'])
# Out:
# Below is an instruction that describes a task. Write a response that appropriately completes the request.
#
# ### Instruction:
# Give three tips for staying healthy.
#
# ### Response:
# 1.Eat a balanced diet and make sure to include plenty of fruits and vegetables.
# 2. Exercise regularly to keep your body active and strong.
# 3. Get enough sleep and maintain a consistent sleep schedule.

# %%
# with input
train_dataset[5]
# Out:
# {'instruction': 'Identify the odd one out.',
#  'input': 'Twitter, Instagram, Telegram',
#  'output': 'Telegram',
#  'text': 'Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n\n### Instruction:\nIdentify the odd one out.\n\n### Input:\nTwitter, Instagram, Telegram\n\n### Response:\nTelegram'}

# %%
print(train_dataset[5]['text'])
# Out:
# Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Identify the odd one out.
#
# ### Input:
# Twitter, Instagram, Telegram
#
# ### Response:
# Telegram

# %% [markdown]
# ## Tokenizer & Model

# %%
model_ckpt = "yahma/llama-7b-hf"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
# Out:
# tokenizer_config.json:   0%|          | 0.00/207 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama_fast.LlamaTokenizerFast'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565 - if you loaded a llama tokenizer from a GGUF file you can ignore this message.

# %%
tokenizer
# Out:
# LlamaTokenizerFast(name_or_path='yahma/llama-7b-hf', vocab_size=32000, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='left', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'pad_token': '</s>'}, clean_up_tokenization_spaces=False),  added_tokens_decoder={
# 	0: AddedToken("<unk>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	1: AddedToken("<s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	2: AddedToken("</s>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# }

# %%
save_path = "../../autodl-fs/model_path"

model = AutoModelForCausalLM.from_pretrained(
    model_ckpt, 
    load_in_4bit=True, 
    torch_dtype=torch.float16, 
    device_map="auto", 
    cache_dir=save_path
)
# Out:
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
for i, (name, layer) in enumerate(model.named_parameters()):
    print(i, name, layer.dtype, layer.device)
    # print(i, layer.dtype, layer.device)
# Out:
# 0 model.embed_tokens.weight torch.float16 cuda:0
# 1 model.layers.0.self_attn.q_proj.weight torch.uint8 cuda:0
# 2 model.layers.0.self_attn.k_proj.weight torch.uint8 cuda:0
# 3 model.layers.0.self_attn.v_proj.weight torch.uint8 cuda:0
# 4 model.layers.0.self_attn.o_proj.weight torch.uint8 cuda:0
# 5 model.layers.0.mlp.gate_proj.weight torch.uint8 cuda:0
# 6 model.layers.0.mlp.up_proj.weight torch.uint8 cuda:0
# 7 model.layers.0.mlp.down_proj.weight torch.uint8 cuda:0
# 8 model.layers.0.input_layernorm.weight torch.float16 cuda:0
# 9 model.layers.0.post_attention_layernorm.weight torch.float16 cuda:0
# 10 model.layers.1.self_attn.q_proj.weight torch.uint8 cuda:0
# 11 model.layers.1.self_attn.k_proj.weight torch.uint8 cuda:0
# 12 model.layers.1.self_attn.v_proj.weight torch.uint8 cuda:0
# 13 model.layers.1.self_attn.o_proj.weight torch.uint8 cuda:0
# 14 model.layers.1.mlp.gate_proj.weight torch.uint8 cuda:0
# 15 model.layers.1.mlp.up_proj.weight torch.uint8 cuda:0
# 16 model.layers.1.mlp.down_proj.weight torch.uint8 cuda:0
# 17 model.layers.1.input_layernorm.weight torch.float16 cuda:0
# 18 model.layers.1.post_attention_layernorm.weight torch.float16 cuda:0
# 19 model.layers.2.self_attn.q_proj.weight torch.uint8 cuda:0
# 20 model.layers.2.self_attn.k_proj.weight torch.uint8 cuda:0
# 21 model.layers.2.self_attn.v_proj.weight torch.uint8 cuda:0
# 22 model.layers.2.self_attn.o_proj.weight torch.uint8 cuda:0
# 23 model.layers.2.mlp.gate_proj.weight torch.uint8 cuda:0
# 24 model.layers.2.mlp.up_proj.weight torch.uint8 cuda:0
# 25 model.layers.2.mlp.down_proj.weight torch.uint8 cuda:0
# 26 model.layers.2.input_layernorm.weight torch.float16 cuda:0
# 27 model.layers.2.post_attention_layernorm.weight torch.float16 cuda:0
# 28 model.layers.3.self_attn.q_proj.weight torch.uint8 cuda:0
# 29 model.layers.3.self_attn.k_proj.weight torch.uint8 cuda:0
# 30 model.layers.3.self_attn.v_proj.weight torch.uint8 cuda:0
# 31 model.layers.3.self_attn.o_proj.weight torch.uint8 cuda:0
# 32 model.layers.3.mlp.gate_proj.weight torch.uint8 cuda:0
# 33 model.layers.3.mlp.up_proj.weight torch.uint8 cuda:0
# 34 model.layers.3.mlp.down_proj.weight torch.uint8 cuda:0
# 35 model.layers.3.input_layernorm.weight torch.float16 cuda:0
# 36 model.layers.3.post_attention_layernorm.weight torch.float16 cuda:0
# 37 model.layers.4.self_attn.q_proj.weight torch.uint8 cuda:0
# 38 model.layers.4.self_attn.k_proj.weight torch.uint8 cuda:0
# 39 model.layers.4.self_attn.v_proj.weight torch.uint8 cuda:0
# 40 model.layers.4.self_attn.o_proj.weight torch.uint8 cuda:0
# 41 model.layers.4.mlp.gate_proj.weight torch.uint8 cuda:0
# 42 model.layers.4.mlp.up_proj.weight torch.uint8 cuda:0
# 43 model.layers.4.mlp.down_proj.weight torch.uint8 cuda:0
# 44 model.layers.4.input_layernorm.weight torch.float16 cuda:0
# 45 model.layers.4.post_attention_layernorm.weight torch.float16 cuda:0
# 46 model.layers.5.self_attn.q_proj.weight torch.uint8 cuda:0
# 47 model.layers.5.self_attn.k_proj.weight torch.uint8 cuda:0
# 48 model.layers.5.self_attn.v_proj.weight torch.uint8 cuda:0
# 49 model.layers.5.self_attn.o_proj.weight torch.uint8 cuda:0
# 50 model.layers.5.mlp.gate_proj.weight torch.uint8 cuda:0
# 51 model.layers.5.mlp.up_proj.weight torch.uint8 cuda:0
# 52 model.layers.5.mlp.down_proj.weight torch.uint8 cuda:0
# 53 model.layers.5.input_layernorm.weight torch.float16 cuda:0
# 54 model.layers.5.post_attention_layernorm.weight torch.float16 cuda:0
# 55 model.layers.6.self_attn.q_proj.weight torch.uint8 cuda:0
# 56 model.layers.6.self_attn.k_proj.weight torch.uint8 cuda:0
# 57 model.layers.6.self_attn.v_proj.weight torch.uint8 cuda:0
# 58 model.layers.6.self_attn.o_proj.weight torch.uint8 cuda:0
# 59 model.layers.6.mlp.gate_proj.weight torch.uint8 cuda:0
# 60 model.layers.6.mlp.up_proj.weight torch.uint8 cuda:0
# 61 model.layers.6.mlp.down_proj.weight torch.uint8 cuda:0
# 62 model.layers.6.input_layernorm.weight torch.float16 cuda:0
# 63 model.layers.6.post_attention_layernorm.weight torch.float16 cuda:0
# 64 model.layers.7.self_attn.q_proj.weight torch.uint8 cuda:0
# 65 model.layers.7.self_attn.k_proj.weight torch.uint8 cuda:0
# 66 model.layers.7.self_attn.v_proj.weight torch.uint8 cuda:0
# 67 model.layers.7.self_attn.o_proj.weight torch.uint8 cuda:0
# 68 model.layers.7.mlp.gate_proj.weight torch.uint8 cuda:0
# 69 model.layers.7.mlp.up_proj.weight torch.uint8 cuda:0
# 70 model.layers.7.mlp.down_proj.weight torch.uint8 cuda:0
# 71 model.layers.7.input_layernorm.weight torch.float16 cuda:0
# 72 model.layers.7.post_attention_layernorm.weight torch.float16 cuda:0
# 73 model.layers.8.self_attn.q_proj.weight torch.uint8 cuda:0
# 74 model.layers.8.self_attn.k_proj.weight torch.uint8 cuda:0
# 75 model.layers.8.self_attn.v_proj.weight torch.uint8 cuda:0
# 76 model.layers.8.self_attn.o_proj.weight torch.uint8 cuda:0
# 77 model.layers.8.mlp.gate_proj.weight torch.uint8 cuda:0
# 78 model.layers.8.mlp.up_proj.weight torch.uint8 cuda:0
# 79 model.layers.8.mlp.down_proj.weight torch.uint8 cuda:0
# 80 model.layers.8.input_layernorm.weight torch.float16 cuda:0
# 81 model.layers.8.post_attention_layernorm.weight torch.float16 cuda:0
# 82 model.layers.9.self_attn.q_proj.weight torch.uint8 cuda:0
# 83 model.layers.9.self_attn.k_proj.weight torch.uint8 cuda:0
# 84 model.layers.9.self_attn.v_proj.weight torch.uint8 cuda:0
# 85 model.layers.9.self_attn.o_proj.weight torch.uint8 cuda:0
# 86 model.layers.9.mlp.gate_proj.weight torch.uint8 cuda:0
# 87 model.layers.9.mlp.up_proj.weight torch.uint8 cuda:0
# 88 model.layers.9.mlp.down_proj.weight torch.uint8 cuda:0
# 89 model.layers.9.input_layernorm.weight torch.float16 cuda:0
# 90 model.layers.9.post_attention_layernorm.weight torch.float16 cuda:0
# 91 model.layers.10.self_attn.q_proj.weight torch.uint8 cuda:0
# 92 model.layers.10.self_attn.k_proj.weight torch.uint8 cuda:0
# 93 model.layers.10.self_attn.v_proj.weight torch.uint8 cuda:0
# 94 model.layers.10.self_attn.o_proj.weight torch.uint8 cuda:0
# 95 model.layers.10.mlp.gate_proj.weight torch.uint8 cuda:0
# 96 model.layers.10.mlp.up_proj.weight torch.uint8 cuda:0
# 97 model.layers.10.mlp.down_proj.weight torch.uint8 cuda:0
# 98 model.layers.10.input_layernorm.weight torch.float16 cuda:0
# 99 model.layers.10.post_attention_layernorm.weight torch.float16 cuda:0
# 100 model.layers.11.self_attn.q_proj.weight torch.uint8 cuda:0
# 101 model.layers.11.self_attn.k_proj.weight torch.uint8 cuda:0
# 102 model.layers.11.self_attn.v_proj.weight torch.uint8 cuda:0
# 103 model.layers.11.self_attn.o_proj.weight torch.uint8 cuda:0
# 104 model.layers.11.mlp.gate_proj.weight torch.uint8 cuda:0
# 105 model.layers.11.mlp.up_proj.weight torch.uint8 cuda:0
# 106 model.layers.11.mlp.down_proj.weight torch.uint8 cuda:0
# 107 model.layers.11.input_layernorm.weight torch.float16 cuda:0
# 108 model.layers.11.post_attention_layernorm.weight torch.float16 cuda:0
# 109 model.layers.12.self_attn.q_proj.weight torch.uint8 cuda:0
# 110 model.layers.12.self_attn.k_proj.weight torch.uint8 cuda:0
# 111 model.layers.12.self_attn.v_proj.weight torch.uint8 cuda:0
# 112 model.layers.12.self_attn.o_proj.weight torch.uint8 cuda:0
# 113 model.layers.12.mlp.gate_proj.weight torch.uint8 cuda:0
# 114 model.layers.12.mlp.up_proj.weight torch.uint8 cuda:0
# 115 model.layers.12.mlp.down_proj.weight torch.uint8 cuda:0
# 116 model.layers.12.input_layernorm.weight torch.float16 cuda:0
# 117 model.layers.12.post_attention_layernorm.weight torch.float16 cuda:0
# 118 model.layers.13.self_attn.q_proj.weight torch.uint8 cuda:0
# 119 model.layers.13.self_attn.k_proj.weight torch.uint8 cuda:0
# 120 model.layers.13.self_attn.v_proj.weight torch.uint8 cuda:0
# 121 model.layers.13.self_attn.o_proj.weight torch.uint8 cuda:0
# 122 model.layers.13.mlp.gate_proj.weight torch.uint8 cuda:0
# 123 model.layers.13.mlp.up_proj.weight torch.uint8 cuda:0
# 124 model.layers.13.mlp.down_proj.weight torch.uint8 cuda:0
# 125 model.layers.13.input_layernorm.weight torch.float16 cuda:0
# 126 model.layers.13.post_attention_layernorm.weight torch.float16 cuda:0
# 127 model.layers.14.self_attn.q_proj.weight torch.uint8 cuda:0
# 128 model.layers.14.self_attn.k_proj.weight torch.uint8 cuda:0
# 129 model.layers.14.self_attn.v_proj.weight torch.uint8 cuda:0
# 130 model.layers.14.self_attn.o_proj.weight torch.uint8 cuda:0
# 131 model.layers.14.mlp.gate_proj.weight torch.uint8 cuda:0
# 132 model.layers.14.mlp.up_proj.weight torch.uint8 cuda:0
# 133 model.layers.14.mlp.down_proj.weight torch.uint8 cuda:0
# 134 model.layers.14.input_layernorm.weight torch.float16 cuda:0
# 135 model.layers.14.post_attention_layernorm.weight torch.float16 cuda:0
# 136 model.layers.15.self_attn.q_proj.weight torch.uint8 cuda:0
# 137 model.layers.15.self_attn.k_proj.weight torch.uint8 cuda:0
# 138 model.layers.15.self_attn.v_proj.weight torch.uint8 cuda:0
# 139 model.layers.15.self_attn.o_proj.weight torch.uint8 cuda:0
# 140 model.layers.15.mlp.gate_proj.weight torch.uint8 cuda:0
# 141 model.layers.15.mlp.up_proj.weight torch.uint8 cuda:0
# 142 model.layers.15.mlp.down_proj.weight torch.uint8 cuda:0
# 143 model.layers.15.input_layernorm.weight torch.float16 cuda:0
# 144 model.layers.15.post_attention_layernorm.weight torch.float16 cuda:0
# 145 model.layers.16.self_attn.q_proj.weight torch.uint8 cuda:0
# 146 model.layers.16.self_attn.k_proj.weight torch.uint8 cuda:0
# 147 model.layers.16.self_attn.v_proj.weight torch.uint8 cuda:0
# 148 model.layers.16.self_attn.o_proj.weight torch.uint8 cuda:0
# 149 model.layers.16.mlp.gate_proj.weight torch.uint8 cuda:0
# 150 model.layers.16.mlp.up_proj.weight torch.uint8 cuda:0
# 151 model.layers.16.mlp.down_proj.weight torch.uint8 cuda:0
# 152 model.layers.16.input_layernorm.weight torch.float16 cuda:0
# 153 model.layers.16.post_attention_layernorm.weight torch.float16 cuda:0
# 154 model.layers.17.self_attn.q_proj.weight torch.uint8 cuda:0
# 155 model.layers.17.self_attn.k_proj.weight torch.uint8 cuda:0
# 156 model.layers.17.self_attn.v_proj.weight torch.uint8 cuda:0
# 157 model.layers.17.self_attn.o_proj.weight torch.uint8 cuda:0
# 158 model.layers.17.mlp.gate_proj.weight torch.uint8 cuda:0
# 159 model.layers.17.mlp.up_proj.weight torch.uint8 cuda:0
# 160 model.layers.17.mlp.down_proj.weight torch.uint8 cuda:0
# 161 model.layers.17.input_layernorm.weight torch.float16 cuda:0
# 162 model.layers.17.post_attention_layernorm.weight torch.float16 cuda:0
# 163 model.layers.18.self_attn.q_proj.weight torch.uint8 cuda:0
# 164 model.layers.18.self_attn.k_proj.weight torch.uint8 cuda:0
# 165 model.layers.18.self_attn.v_proj.weight torch.uint8 cuda:0
# 166 model.layers.18.self_attn.o_proj.weight torch.uint8 cuda:0
# 167 model.layers.18.mlp.gate_proj.weight torch.uint8 cuda:0
# 168 model.layers.18.mlp.up_proj.weight torch.uint8 cuda:0
# 169 model.layers.18.mlp.down_proj.weight torch.uint8 cuda:0
# 170 model.layers.18.input_layernorm.weight torch.float16 cuda:0
# 171 model.layers.18.post_attention_layernorm.weight torch.float16 cuda:0
# 172 model.layers.19.self_attn.q_proj.weight torch.uint8 cuda:0
# 173 model.layers.19.self_attn.k_proj.weight torch.uint8 cuda:0
# 174 model.layers.19.self_attn.v_proj.weight torch.uint8 cuda:0
# 175 model.layers.19.self_attn.o_proj.weight torch.uint8 cuda:0
# 176 model.layers.19.mlp.gate_proj.weight torch.uint8 cuda:0
# 177 model.layers.19.mlp.up_proj.weight torch.uint8 cuda:0
# 178 model.layers.19.mlp.down_proj.weight torch.uint8 cuda:0
# 179 model.layers.19.input_layernorm.weight torch.float16 cuda:0
# 180 model.layers.19.post_attention_layernorm.weight torch.float16 cuda:0
# 181 model.layers.20.self_attn.q_proj.weight torch.uint8 cuda:0
# 182 model.layers.20.self_attn.k_proj.weight torch.uint8 cuda:0
# 183 model.layers.20.self_attn.v_proj.weight torch.uint8 cuda:0
# 184 model.layers.20.self_attn.o_proj.weight torch.uint8 cuda:0
# 185 model.layers.20.mlp.gate_proj.weight torch.uint8 cuda:0
# 186 model.layers.20.mlp.up_proj.weight torch.uint8 cuda:0
# 187 model.layers.20.mlp.down_proj.weight torch.uint8 cuda:0
# 188 model.layers.20.input_layernorm.weight torch.float16 cuda:0
# 189 model.layers.20.post_attention_layernorm.weight torch.float16 cuda:0
# 190 model.layers.21.self_attn.q_proj.weight torch.uint8 cuda:0
# 191 model.layers.21.self_attn.k_proj.weight torch.uint8 cuda:0
# 192 model.layers.21.self_attn.v_proj.weight torch.uint8 cuda:0
# 193 model.layers.21.self_attn.o_proj.weight torch.uint8 cuda:0
# 194 model.layers.21.mlp.gate_proj.weight torch.uint8 cuda:0
# 195 model.layers.21.mlp.up_proj.weight torch.uint8 cuda:0
# 196 model.layers.21.mlp.down_proj.weight torch.uint8 cuda:0
# 197 model.layers.21.input_layernorm.weight torch.float16 cuda:0
# 198 model.layers.21.post_attention_layernorm.weight torch.float16 cuda:0
# 199 model.layers.22.self_attn.q_proj.weight torch.uint8 cuda:0
# 200 model.layers.22.self_attn.k_proj.weight torch.uint8 cuda:0
# 201 model.layers.22.self_attn.v_proj.weight torch.uint8 cuda:0
# 202 model.layers.22.self_attn.o_proj.weight torch.uint8 cuda:0
# 203 model.layers.22.mlp.gate_proj.weight torch.uint8 cuda:0
# 204 model.layers.22.mlp.up_proj.weight torch.uint8 cuda:0
# 205 model.layers.22.mlp.down_proj.weight torch.uint8 cuda:0
# 206 model.layers.22.input_layernorm.weight torch.float16 cuda:0
# 207 model.layers.22.post_attention_layernorm.weight torch.float16 cuda:0
# 208 model.layers.23.self_attn.q_proj.weight torch.uint8 cuda:0
# 209 model.layers.23.self_attn.k_proj.weight torch.uint8 cuda:0
# 210 model.layers.23.self_attn.v_proj.weight torch.uint8 cuda:0
# 211 model.layers.23.self_attn.o_proj.weight torch.uint8 cuda:0
# 212 model.layers.23.mlp.gate_proj.weight torch.uint8 cuda:0
# 213 model.layers.23.mlp.up_proj.weight torch.uint8 cuda:0
# 214 model.layers.23.mlp.down_proj.weight torch.uint8 cuda:0
# 215 model.layers.23.input_layernorm.weight torch.float16 cuda:0
# 216 model.layers.23.post_attention_layernorm.weight torch.float16 cuda:0
# 217 model.layers.24.self_attn.q_proj.weight torch.uint8 cuda:0
# 218 model.layers.24.self_attn.k_proj.weight torch.uint8 cuda:0
# 219 model.layers.24.self_attn.v_proj.weight torch.uint8 cuda:0
# 220 model.layers.24.self_attn.o_proj.weight torch.uint8 cuda:0
# 221 model.layers.24.mlp.gate_proj.weight torch.uint8 cuda:0
# 222 model.layers.24.mlp.up_proj.weight torch.uint8 cuda:0
# 223 model.layers.24.mlp.down_proj.weight torch.uint8 cuda:0
# 224 model.layers.24.input_layernorm.weight torch.float16 cuda:0
# 225 model.layers.24.post_attention_layernorm.weight torch.float16 cuda:0
# 226 model.layers.25.self_attn.q_proj.weight torch.uint8 cuda:0
# 227 model.layers.25.self_attn.k_proj.weight torch.uint8 cuda:0
# 228 model.layers.25.self_attn.v_proj.weight torch.uint8 cuda:0
# 229 model.layers.25.self_attn.o_proj.weight torch.uint8 cuda:0
# 230 model.layers.25.mlp.gate_proj.weight torch.uint8 cuda:0
# 231 model.layers.25.mlp.up_proj.weight torch.uint8 cuda:0
# 232 model.layers.25.mlp.down_proj.weight torch.uint8 cuda:0
# 233 model.layers.25.input_layernorm.weight torch.float16 cuda:0
# 234 model.layers.25.post_attention_layernorm.weight torch.float16 cuda:0
# 235 model.layers.26.self_attn.q_proj.weight torch.uint8 cuda:0
# 236 model.layers.26.self_attn.k_proj.weight torch.uint8 cuda:0
# 237 model.layers.26.self_attn.v_proj.weight torch.uint8 cuda:0
# 238 model.layers.26.self_attn.o_proj.weight torch.uint8 cuda:0
# 239 model.layers.26.mlp.gate_proj.weight torch.uint8 cuda:0
# 240 model.layers.26.mlp.up_proj.weight torch.uint8 cuda:0
# 241 model.layers.26.mlp.down_proj.weight torch.uint8 cuda:0
# 242 model.layers.26.input_layernorm.weight torch.float16 cuda:0
# 243 model.layers.26.post_attention_layernorm.weight torch.float16 cuda:0
# 244 model.layers.27.self_attn.q_proj.weight torch.uint8 cuda:0
# 245 model.layers.27.self_attn.k_proj.weight torch.uint8 cuda:0
# 246 model.layers.27.self_attn.v_proj.weight torch.uint8 cuda:0
# 247 model.layers.27.self_attn.o_proj.weight torch.uint8 cuda:0
# 248 model.layers.27.mlp.gate_proj.weight torch.uint8 cuda:0
# 249 model.layers.27.mlp.up_proj.weight torch.uint8 cuda:0
# 250 model.layers.27.mlp.down_proj.weight torch.uint8 cuda:0
# 251 model.layers.27.input_layernorm.weight torch.float16 cuda:0
# 252 model.layers.27.post_attention_layernorm.weight torch.float16 cuda:0
# 253 model.layers.28.self_attn.q_proj.weight torch.uint8 cuda:0
# 254 model.layers.28.self_attn.k_proj.weight torch.uint8 cuda:0
# 255 model.layers.28.self_attn.v_proj.weight torch.uint8 cuda:0
# 256 model.layers.28.self_attn.o_proj.weight torch.uint8 cuda:0
# 257 model.layers.28.mlp.gate_proj.weight torch.uint8 cuda:0
# 258 model.layers.28.mlp.up_proj.weight torch.uint8 cuda:0
# 259 model.layers.28.mlp.down_proj.weight torch.uint8 cuda:0
# 260 model.layers.28.input_layernorm.weight torch.float16 cuda:0
# 261 model.layers.28.post_attention_layernorm.weight torch.float16 cuda:0
# 262 model.layers.29.self_attn.q_proj.weight torch.uint8 cuda:0
# 263 model.layers.29.self_attn.k_proj.weight torch.uint8 cuda:0
# 264 model.layers.29.self_attn.v_proj.weight torch.uint8 cuda:0
# 265 model.layers.29.self_attn.o_proj.weight torch.uint8 cuda:0
# 266 model.layers.29.mlp.gate_proj.weight torch.uint8 cuda:0
# 267 model.layers.29.mlp.up_proj.weight torch.uint8 cuda:0
# 268 model.layers.29.mlp.down_proj.weight torch.uint8 cuda:0
# 269 model.layers.29.input_layernorm.weight torch.float16 cuda:0
# 270 model.layers.29.post_attention_layernorm.weight torch.float16 cuda:0
# 271 model.layers.30.self_attn.q_proj.weight torch.uint8 cuda:0
# 272 model.layers.30.self_attn.k_proj.weight torch.uint8 cuda:0
# 273 model.layers.30.self_attn.v_proj.weight torch.uint8 cuda:0
# 274 model.layers.30.self_attn.o_proj.weight torch.uint8 cuda:0
# 275 model.layers.30.mlp.gate_proj.weight torch.uint8 cuda:0
# 276 model.layers.30.mlp.up_proj.weight torch.uint8 cuda:0
# 277 model.layers.30.mlp.down_proj.weight torch.uint8 cuda:0
# 278 model.layers.30.input_layernorm.weight torch.float16 cuda:0
# 279 model.layers.30.post_attention_layernorm.weight torch.float16 cuda:0
# 280 model.layers.31.self_attn.q_proj.weight torch.uint8 cuda:0
# 281 model.layers.31.self_attn.k_proj.weight torch.uint8 cuda:0
# 282 model.layers.31.self_attn.v_proj.weight torch.uint8 cuda:0
# 283 model.layers.31.self_attn.o_proj.weight torch.uint8 cuda:0
# 284 model.layers.31.mlp.gate_proj.weight torch.uint8 cuda:0
# 285 model.layers.31.mlp.up_proj.weight torch.uint8 cuda:0
# 286 model.layers.31.mlp.down_proj.weight torch.uint8 cuda:0
# 287 model.layers.31.input_layernorm.weight torch.float16 cuda:0
# 288 model.layers.31.post_attention_layernorm.weight torch.float16 cuda:0
# 289 model.norm.weight torch.float16 cuda:0
# 290 lm_head.weight torch.float16 cuda:0

# %%
model
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(32000, 4096, padding_idx=0)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-06)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-06)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-06)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
# )

# %% [markdown]
# ## PEFT model

# %%
model = prepare_model_for_kbit_training(model)

# %%
peft_config = LoraConfig(r=16, lora_alpha=32, lora_dropout=0.05, bias="none", task_type="CAUSAL_LM")
model = get_peft_model(model, peft_config)

# %%
training_args = TrainingArguments(
        output_dir="trained_model",
        per_device_train_batch_size=4,
        optim="adamw_torch",
        logging_steps=10,
        learning_rate=2e-4,
        fp16=True,
        warmup_ratio=0.1,
        lr_scheduler_type="linear",
        num_train_epochs=1,
        save_strategy="epoch",
        push_to_hub=False,
        report_to="none"
    )
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset,
    dataset_text_field="text",
    max_seq_length=1024,
    tokenizer=tokenizer,
    args=training_args,
    packing=True,
    peft_config=peft_config,
)
trainer.train()
# Out:
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field, max_seq_length, packing. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/trl/trainer/sft_trainer.py:195: UserWarning: You passed a `packing` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/trl/trainer/sft_trainer.py:283: UserWarning: You passed a `max_seq_length` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/trl/trainer/sft_trainer.py:321: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/trl/trainer/sft_trainer.py:396: UserWarning: You passed a tokenizer with `padding_side` not equal to `right` to the SFTTrainer. This might lead to some unexpected behaviour due to overflow issues when training a model in half-precision. You might consider adding `tokenizer.padding_side = 'right'` to your code.
#   warnings.warn(
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/bitsandbytes/nn/modules.py:452: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/utils/checkpoint.py:295: FutureWarning: `torch.cpu.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cpu', args...)` instead.
#   with torch.enable_grad(), device_autocast_ctx, torch.cpu.amp.autocast(**ctx.cpu_autocast_kwargs):  # type: ignore[attr-defined]
#     <div>
#
#       <progress value='1627' max='1627' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1627/1627 1:25:09, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.680000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.648600</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.433100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.303800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.231400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.164700</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.097000</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.001000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.980300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.940700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.983200</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.962200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.937600</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.922100</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.950000</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.932700</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.914200</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>0.940600</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>0.912700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.932500</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>0.888100</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.914100</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.903300</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.909500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.911300</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.898300</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>0.902900</td>
#     </tr>
#     <tr>
#       <td>280</td>
#       <td>0.922200</td>
#     </tr>
#     <tr>
#       <td>290</td>
#       <td>0.916900</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.893300</td>
#     </tr>
#     <tr>
#       <td>310</td>
#       <td>0.892200</td>
#     </tr>
#     <tr>
#       <td>320</td>
#       <td>0.950400</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>0.885600</td>
#     </tr>
#     <tr>
#       <td>340</td>
#       <td>0.929300</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.888400</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>0.911800</td>
#     </tr>
#     <tr>
#       <td>370</td>
#       <td>0.892200</td>
#     </tr>
#     <tr>
#       <td>380</td>
#       <td>0.866200</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>0.908000</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.880600</td>
#     </tr>
#     <tr>
#       <td>410</td>
#       <td>0.920400</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>0.865100</td>
#     </tr>
#     <tr>
#       <td>430</td>
#       <td>0.889200</td>
#     </tr>
#     <tr>
#       <td>440</td>
#       <td>0.886600</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.894800</td>
#     </tr>
#     <tr>
#       <td>460</td>
#       <td>0.932400</td>
#     </tr>
#     <tr>
#       <td>470</td>
#       <td>0.881400</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>0.875400</td>
#     </tr>
#     <tr>
#       <td>490</td>
#       <td>0.887200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.911500</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.884200</td>
#     </tr>
#     <tr>
#       <td>520</td>
#       <td>0.899900</td>
#     </tr>
#     <tr>
#       <td>530</td>
#       <td>0.910500</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.889100</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.891700</td>
#     </tr>
#     <tr>
#       <td>560</td>
#       <td>0.885700</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.903600</td>
#     </tr>
#     <tr>
#       <td>580</td>
#       <td>0.918400</td>
#     </tr>
#     <tr>
#       <td>590</td>
#       <td>0.887800</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.874000</td>
#     </tr>
#     <tr>
#       <td>610</td>
#       <td>0.890000</td>
#     </tr>
#     <tr>
#       <td>620</td>
#       <td>0.906000</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.878700</td>
#     </tr>
#     <tr>
#       <td>640</td>
#       <td>0.891300</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.858600</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.904900</td>
#     </tr>
#     <tr>
#       <td>670</td>
#       <td>0.905400</td>
#     </tr>
#     <tr>
#       <td>680</td>
#       <td>0.885800</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.879800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.894500</td>
#     </tr>
#     <tr>
#       <td>710</td>
#       <td>0.901000</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.916900</td>
#     </tr>
#     <tr>
#       <td>730</td>
#       <td>0.857200</td>
#     </tr>
#     <tr>
#       <td>740</td>
#       <td>0.875800</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.893500</td>
#     </tr>
#     <tr>
#       <td>760</td>
#       <td>0.860700</td>
#     </tr>
#     <tr>
#       <td>770</td>
#       <td>0.855000</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.841200</td>
#     </tr>
#     <tr>
#       <td>790</td>
#       <td>0.891200</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.890600</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.859900</td>
#     </tr>
#     <tr>
#       <td>820</td>
#       <td>0.863600</td>
#     </tr>
#     <tr>
#       <td>830</td>
#       <td>0.884200</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.878000</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.878800</td>
#     </tr>
#     <tr>
#       <td>860</td>
#       <td>0.882800</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.891300</td>
#     </tr>
#     <tr>
#       <td>880</td>
#       <td>0.887100</td>
#     </tr>
#     <tr>
#       <td>890</td>
#       <td>0.903800</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.871400</td>
#     </tr>
#     <tr>
#       <td>910</td>
#       <td>0.896300</td>
#     </tr>
#     <tr>
#       <td>920</td>
#       <td>0.879300</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.913700</td>
#     </tr>
#     <tr>
#       <td>940</td>
#       <td>0.910700</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.908200</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.885600</td>
#     </tr>
#     <tr>
#       <td>970</td>
#       <td>0.899600</td>
#     </tr>
#     <tr>
#       <td>980</td>
#       <td>0.872800</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.884900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.891900</td>
#     </tr>
#     <tr>
#       <td>1010</td>
#       <td>0.868200</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.907300</td>
#     </tr>
#     <tr>
#       <td>1030</td>
#       <td>0.863600</td>
#     </tr>
#     <tr>
#       <td>1040</td>
#       <td>0.852800</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.876800</td>
#     </tr>
#     <tr>
#       <td>1060</td>
#       <td>0.892200</td>
#     </tr>
#     <tr>
#       <td>1070</td>
#       <td>0.893600</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.879500</td>
#     </tr>
#     <tr>
#       <td>1090</td>
#       <td>0.879600</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.907400</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.891000</td>
#     </tr>
#     <tr>
#       <td>1120</td>
#       <td>0.880500</td>
#     </tr>
#     <tr>
#       <td>1130</td>
#       <td>0.864500</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.904200</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.869100</td>
#     </tr>
#     <tr>
#       <td>1160</td>
#       <td>0.896000</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.839100</td>
#     </tr>
#     <tr>
#       <td>1180</td>
#       <td>0.895200</td>
#     </tr>
#     <tr>
#       <td>1190</td>
#       <td>0.914200</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.871800</td>
#     </tr>
#     <tr>
#       <td>1210</td>
#       <td>0.885300</td>
#     </tr>
#     <tr>
#       <td>1220</td>
#       <td>0.881000</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.897700</td>
#     </tr>
#     <tr>
#       <td>1
# /root/miniconda3/envs/nlp_study/lib/python3.8/site-packages/torch/_dynamo/eval_frame.py:600: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.4 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# TrainOutput(global_step=1627, training_loss=0.9121827068106119, metrics={'train_runtime': 5113.404, 'train_samples_per_second': 1.272, 'train_steps_per_second': 0.318, 'total_flos': 2.6444976445036954e+17, 'train_loss': 0.9121827068106119, 'epoch': 1.0})
